# %%
from IPython.display import Image
import matplotlib.pyplot as plt
import numpy as np

g = 9.8 #m/s^2
R = 8.314 #K/mole K

ndigits = 2

# %% [markdown]
# # Esercizi di Termodinamica

# %% [markdown]
# Gli esercizi proposti sono tratti da:
#
# 1. Mazzoldi Saggion Voci : Problemi di Fisica generale (MSV)
# 2. Mazzoldi Nigro Voci : Fisica Vol. 1(MNV)
# 3. Temi d'esame (TE)

# %% [markdown]
# __Programma (orientativo)__
#
# Esercizi svolti : dal 9.1 al 9.4, 9.8, 9.9, 9.13, 9.15, 9.18
#
# Cap 10 : 4, 17, 22, 35, 37, 40, 42, 45, 46, 48, 50, 51, 56, 39, 53
#
# Consigliati : Cap 9 dal 1 al 15 e il 19
# Cap 10 : dal 2 al 12, dal 15 al 23, dal 27 al 33, dal 35 al 57
#
# __Lezione 9 (12 Maggio)__
#
# Esercizio proposti MSV : 9.1, 9.2, 9.3, 9.8, 9.9, 9.13.
#
# __Lezione 10 (19 Maggio)__
#
# Esercizio proposti MSV : 9.15, 9.18, 10.4, 10.17, 10.22,
#
# __Lezione 11 (26 Maggio)__
#
# Esercizio proposti MSV :

# %% [markdown]
# ## MSV - Esercizio 9.1

# %%
Image('Immagini/MSV_9.1_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# I sistemi alluminio e acqua+vetro scambiano calore fra di loro (e trascuriamo gli scambi verso l'ambiente)
# fino a raggiungere una temperatura di equilibrio comune al sistema complessivo.
#
# In particolare l'alluminio, che si trova a temperatura maggiore cede calore al sistema acqua+vetro e
# l'equazione di bilancio termico si può scrivere come
# $$
# \Delta Q_{al}+\Delta Q_{a+v} = 0
# $$
# Esprimiamo quindi il calore ceduto (o assorbito) da una parte del sistema in termini della sua varazione di
# temperatura, in particolare
# $$
# \Delta Q_{al} = m_1 c_1(T_{e}-T_1) \, , \quad
# \Delta Q_{a+v} = (m_2 c_2+m_3 c_3) (T_{e}-T_2)
# $$
# Notate che $T_{e}$ sarà compresa fra $T_2$ e $T_1$ quindi $\Delta Q_{al} < 0$ mentre $\Delta Q_{a+v} > 0$.
# Sostituendo queste relazioni nell'equazione di equilibrio termico troviamo la temperatura di equilibrio
# $$
# T_{e} = \frac{m_1 c_1 T_1 + (m_2 c_2+m_3 c_3)T_2}{m_1 c_1+m_2 c_2 + m_3 c_3}
# $$
# Infine controlliamo che tutte le unità di misura siano consistenti e sostituiamo i valori numerici per il calcolo.
#
# Si ottiene $T_{e}=324.2 K$, questo valore è inferiore alla temperatura di ebollizione dell'acqua e quindi
# il metodo usato per il calcolo è a posteriori giustificato.

# %% [markdown]
# ## MSV - Esercizio 9.2

# %%
Image('Immagini/MSV_9.2_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# L'equazione di bilancio termico si scrive come
# $$
# \Delta Q_1 + \Delta Q_2 + \Delta Q_3 = 0
# $$
# e esprimendo gli scambi di calore in funzione delle variazione di temperatura abbiamo
# $$
# m_1(T_e-T_1)+m_2(T_e-T_2)+m_3(T_e-T_3) = 0
# $$
# notate che abbiamo potuto dividere per il  calore specifico dell'acqua, comune a tutte e tre le masse.
# Troviamo quindi
# $$
# T_e = \frac{m_1T_1+m_2T_2+m_3T_3}{m_1+m_2+m_3}
# $$
# da cui segue $T_e=316.7 K$.

# %% [markdown]
# ## MSV - Esercizio 9.3

# %%
Image('Immagini/MSV_9.3_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Impostiamo l'equazione di bilancio termico alla quala partecipa anche il calorimetro con la sua
# capacità termica
# $$
# m_2 c_2(T_e-T_2) + (m_1 c_1+C)(T_e-T_1) = 0
# $$
# da cui otteniamo l'espressione per il calore specifico del rame
# $$
# c_2 = \frac{(m_1 c_1+C)(T_e-T_1)}{m_2(T_2-T_e)} = 401.6 J/KgK
# $$

# %% [markdown]
# ## MSV - Esercizio 9.8

# %%
Image('Immagini/MSV_9.8_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Bisogna valutare le quantità di calore che i sottosistemi acqua e ghiaccio sono in grado di fornire (e che
# necessitano di assorbire) nei processi che possono avvenire (fusione del ghiaccio e/o congelamento
# dell'acqua).
#
# Analizziamo il calore necessario per portare il ghiaccio alla temperatura di fusione
# ($T_f=273 K$)
# $$
# Q_1 = m_1c_1(T_f-T_1)
# $$
# e numericamente vale $Q_1 = 1.23\times 10^5 J$. Analizziamo anche il calore necessario per fondere il
# ghiaccio, che si esprime come
# $$
# Q_f = m_1\lambda_f
# $$
# e numericamente vale $Q_f = 9.9\times 10^5 J$.
#
# Questi processi avvengono a discapito del calore fornito dall'acqua bollente che di conseguenza si raffredda.
# Il massimo calore che può fornire corrisponde a una varazione di temperatura di $100 K$, che comporta
# una quantità di calore ceduto (preso con il segno positivo!)
# $$
# Q_2 = m_2 c_2 (T_2-T_f)
# $$
# numericamente pari a $Q_2 = 4.187\times 10^5 J$.
#
# Osserviamo che $Q_2 > Q_1$ quindi il ghiaccio viene portato alla tempertatura di fusione, ma $Q_2$ non
# è sufficiente per fondere tutto il ghiaccio. La quantità fusa si calcola come
# $$
# m_f\lambda_f = Q_2-Q_1
# $$
# da cui calcoliamo $m_f = 0.896 Kg$. All'equilibrio si hanno quindi $1.896 Kg$ di acqua e $2.103 Kg$ di ghiaccio,
# entrambi a $273 K$.

# %% [markdown]
# ## MSV - Esercizio 9.9

# %%
Image('Immagini/MSV_9.9_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Si tratta di una trasformazione a volume costante (recipiente a pareti rigide). Dobbiamo calcolare la
# temperatura di equilibrio del sistema e poi determinare la pressione di equilibrio del gas usando
# l'equazione di stato dei gas perfetti.
#
# L'equazione di bilancio termico si scrive
# $$
# m_1 c_1 (T_e-T_1) + n c_v (T_e - T_0) = 0
# $$
# dove $c_v$ è il calore specifico (molare) a volume costante dell'ossigeno. Siccome la molecola di ossigeno
# è biatomica abbiamo
# $$
# c_v = \frac{5}{2} R  = 20.77 J/mole K
# $$
# Otteniamo quindi
# $$
# T_e = \frac{m_1c_1T_1+n c_v T_0}{m_1 c_1+ n c_v}
# $$
# e numericamente abbiamo $T_e = 541.15 K$.
#
# Per determinare la pressione finale usiamo l'equazione di stato dei gas perfetti e
# sfruttiamo il fatto che il volume si mantiene costante. Abbiamo quindi
# $$
# \frac{nRT_0}{P_0} = \frac{nRT_e}{P_e} \, , \quad \rightarrow \quad
# P_e = P_0 \frac{T_e}{T_0}
# $$
# da cui segue $P_e = 1.8$ bar.

# %% [markdown]
# ## MSV - Esercizio 9.13

# %%
Image('Immagini/MSV_9.13_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Dopo l'apertura del setto avviene una espansione libera del gas. In questa trasformazione il gas non compie
# lavoro e non c'è scambio di calore verso l'esterno visto che le pareti esterne sono adiabatiche.
# Di conseguenza $\Delta U = 0$ e la trasformazione avviene a temperatura costante. Ragggiunto l'equilibrio
# il volume occupato dal gas è pari a $2V_1$ e la sua pressione è dimezzata.
#
# La prima compressione è una trasformazione adiabatica reversibile, descritta da
# $$
# T_i V_i^{\gamma-1} = T_f V_f^{\gamma-1}
# $$
# dove $V_f = 1/2 V_i$ e
# $$
# \gamma = \frac{c_p}{c_v} = \frac{5/2}{3/2} = 1.666
# $$
# visto che si tratta di un gas ideale monoatomico. La temperatura finale è quindi data da
# $$
# T_2= T_1 2^{\gamma-1} = 476.2 K
# $$
# Il lavoro associato si calcola come
# $$
# W = -\Delta U = -n c_v (T_2-T_1) = -2197.4 J
# $$
# E' negativo perchè viene compiuto sul sistema (è una compressione).
#
# Ripetendo le operazioni si ha una nuova espansione libera che avviene a temperatura $T_2$
# e una nuova compressione adiabatica che porta il sistema alla temperatura $T_3$, data da
# $$
# T_3= T_2 2^{\gamma-1} = 756 K
# $$
# Il lavoro eseguito nella seconda compressione è dato da
# $$
# W = -\Delta U = -n c_v (T_3-T_2) = -3489 J
# $$
# e quindi risulta (in modulo) maggiore di quello associato alla prima compressione.

# %% [markdown]
# ## MSV - Esercizio 9.15

# %%
Image('Immagini/MSV_9.15_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Scriviamo l'equazione di bilancio termico
# $$
# \Delta Q_B + \Delta Q_A = 0
# $$
# dove
# $$
# \Delta Q_B = n_B c_v(T_e-T_B) \, , \quad
# \Delta Q_A = n_A c_p(T_e-T_A)
# $$
# quindi
# $$
# T_e = \frac{n_A c_p T_A+n_B c_v T_B}{n_A c_p+n_B c_v} = 417.4 K
# $$
# con $c_v = 3/2 R$ perchè è monoatomico, e $c_p = 7/2 R$ perchè è biatomico.
#
# Il volume finale di A è dato alla somma del volume di B e del volume occupato dal gas (in A)
# nello stato di equilibrio finale.
# Il volume occupato dal gas si determina usando l'equazione di stato
# $$
# V_{gas} = \frac{nRT_e}{P_A} = 6.9 \times 10^{-2} m^3
# $$
# quindi il volume di A è
# $$
# V_A = V_{gas}+V_B = 7.9 \times 10^{-2} m^3
# $$

# %% [markdown]
# ## MSV - Esercizio 9.18

# %%
Image('Immagini/MSV_9.18_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Quando si aggiunge il secondo peso si determina uno squilibrio meccanico
# fra la pressione esterna e interna e il gas subisce una compressione isoterma,
# visto che il sistema è in contatto con un bagno termico a temperatura costante.
# Il processo _non_ è reversibile, il lavoro subito dal gas è quello esercitato dalla
# forza di gravità agente sul pistone lungo lo spostamento che porta il gas dal
# volume iniziale a quello finale. Può essere espresso come
# $$
# W = 2mg \frac{V_2-V_1}{S} = -0.6 J
# $$

# %% [markdown]
# Osserviamo che se la compressione fosse avvenuta in modo reversibile, ad esempio attraverso un incremento lento della pressione esterna in modo che il gas
# nel cilindro si fosse trovato sempre in condizioni di equilibrio meccanico con l'esterno, avremmo potuto calcolare il lavoro subito come
# $$
# W = \int _{V_1}^{V_2}p_{gas}(V) dV = nRT \int _{V_1}^{V_2}\frac{dV}{V} = nRT ln\left(\frac{V_2}{V_1}\right)
# $$
# e il fattore $nRT$, costante durante la trasformazione, può essere calcolato usando l'equazione di stato del gas nella configurazione iniziale (o in quella finale)
# $$
# nRT = \frac{mg}{S}{V_1}
# $$
# Otteniamo quindi
# $$
# W = \frac{mg}{S}{V_1} ln\left(\frac{V_2}{V_1}\right) = 0.4 J
# $$
# Otteniamo che se la trasformazione è reversibile il lavoro subito è inferiore (in modulo) a parità di condizioni inziali e finali del sistema.

# %% [markdown]
# ## MSV - Esercizio 10.4

# %%
Image('Immagini/MSV_10.4_Testo1.png',width=900)

# %%
Image('Immagini/MSV_10.4_Testo2.png',width=800)

# %% [markdown]
# __Svolgimento__
#
# Scriviamo l'equazione di bilancio termico del sistema gas  + recipiente. Siccome non ci sono scambi
# di calore verso l'ambiente esterno abbiamo
# $$
# \Delta Q_{g} + \Delta Q_{r} = 0
# $$
# Il gas compie una trasformazione reversibile, quindi possiamo specificare i differenziali come
# $$
# nc_v dT + pdV +k_0 dT = \left(nc_v+k_0\right)dT + nrT \frac{dV}{V} = 0
# $$
# da cui otteniamo, per separazione di variabili
# $$
# \int_{V_A}^{V_B}\frac{dV}{V} = -\int_{T_A}^{T_B}\frac{nc_v+k_0}{nR}\frac{dT}{T}
# $$
# che ci da le relazioni fra stato iniziale e stato finale del sistema
# $$
# ln\left(\frac{V_B}{V_A}\right) = - \frac{nc_v+k_0}{nR}
# ln\left(\frac{T_B}{T_A}\right)
# $$
# Il problema ci fornisce i valori di $T_A,P_A,P_B$, usiamo quindi le equazioni di stato per esprimere le altre variabili
# termodinamiche in funzione di quelle note e calcoliamo $T_A$ dalla relazione precedente.
# Abbiamo
# $$
# ln\left(\frac{P_A}{P_B}\frac{T_B}{T_A}\right) = - \frac{nc_v+k_0}{nR}
# ln\left(\frac{T_B}{T_A}\right)
# $$
# da cui usando la relazione $c_p-c_v=R$
# $$
# \frac{nc_p+k_0}{nR} ln\left(\frac{T_B}{T_A}\right) = ln\left(\frac{P_B}{P_A}\right)
# $$
# e quindi
# $$
# T_B = T_A \left(\frac{P_B}{P_A}\right)^{\frac{nR}{nc_p+k_0}} = 232.7 K
# $$
# Nota la temperatura di equilibrio finale possiamo calcolare il calore assorbito dal gas come
# $$
# \Delta Q_{g} = -\Delta Q_{r} = -k_0(T_B-T_A) = 5047.5 J
# $$
# che essendo positivo è un calore effettivamente assorbito dal gas.
#
# La variazione di energia interna è una funzione di stato e si calcola come
# $$
# \Delta U = n c_v (T_B-T_A) = -1460.4 J
# $$
# e infine il lavoro fatto dal gas è
# $$
# W = Q - \Delta U = 6057.9 J
# $$

# %% [markdown]
# ## MSV - Esercizio 10.17

# %%
Image('Immagini/MSV_10.17_Testo.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# Il gas compie lavoro solamente durante la trasformazione fra A e B, visto che $W_{BC}=0$ in quanto
# la trasformazione fra B e C è isocora. Abbiamo quindi
# $$
# W_{AB} = -\Delta U_{AB} = -n c_v (T_B-T_A)
# $$
# Lo scambio di calore avviene solamente nel tratto BC durante il quale
# $$
# Q_{BC} = \Delta U_{BC} = n c_v(T_C-T_B)
# $$
# La variazione di energia interna nella trasformazione dipende solamente dalla temperatura nello stato
# inziale e finale
# $$
# \Delta U_{AC} = n c_v(T_C-T_A)
# $$

# %% [markdown]
# ## MSV - Esercizio 10.22

# %%
Image('Immagini/MSV_10.22_Testo1.png',width=900)

# %%
Image('Immagini/MSV_10.22_Testo2.png',width=900)

# %% [markdown]
# __Svolgimento__
#
# La temperatura inziale si può calcolare utilizzando l'equazione di stato dei gas perfetti
# $$
# T_i = \frac{P}{nR}\left(V_B+V_C\right)
# $$
#
# Nella prima fase avviene una compressione reversibile isobara. Il lavoro fatto sul gas si esprime come
# $$
# W = P \left( V_B - (V_B+V_C)\right) = - PV_C
# $$
# Durante la compressione isobara valgono le relazioni fra lo stato inziale e finale
# $$
# \frac{T_i}{V_B+V_C} = \frac{T_F}{V_B} \, , \quad \rightarrow \quad
# T_f -T_i = - T_i \frac{V_C}{V_B+V_C}
# $$
# corrispondentemente la variazione di energia interna e il calore sono dati da
# $$
# \Delta U = -n c_v T_i \frac{V_C}{V_B+V_C} \, , \quad
# Q_1 = \Delta U + W
# $$
# Nella successiva espansione libera (non reversibile) il gas non compie lavoro, la variazione di energia interna
# e il calore scambiato sono nulli.
